# %% [markdown]
# # 数据准备
# # 使用dpdata这个库进行数据准备，并且划分为训练和验证集
# ## 下面以abacus数据为示例
# ## 附上deepmd和dpdata的tutorial
# ### https://docs.deepmodeling.com/projects/dpdata/en/master/index.html
# ### https://docs.deepmodeling.com/projects/deepmd/en/master/data/dpdata.html

# %%
! /public/software/mambaforge/envs/deepmd/bin/dp --version
# Out:
# DeePMD-kit v3.0.2

# %%
import dpdata 
import numpy as np

# 加载数据
data = dpdata.LabeledSystem('abacus_md', fmt = 'abacus/md') 
print('# the data contains %d frames' % len(data))

# 随机选择40个数据抽为验证集
index_validation = np.random.choice(201,size=40,replace=False)

# 抽取其他数据作为训练数据
index_training = list(set(range(201))-set(index_validation))
data_training = data.sub_system(index_training)
data_validation = data.sub_system(index_validation)

# 保存为训练数据
data_training.to_deepmd_npy('DeePMD-kit_Tutorial/00.data/training_data')

# 保存验证数据
data_validation.to_deepmd_npy('DeePMD-kit_Tutorial/00.data/validation_data')

print('# the training data contains %d frames' % len(data_training)) 
print('# the validation data contains %d frames' % len(data_validation))
# Out:
# # the data contains 201 frames
# # the training data contains 161 frames
# # the validation data contains 40 frames

# %% [markdown]
# ## 模型参数文件

# %%
import json

data = {
    "_comment": " model parameters",
    "model": {
        "type_map": ["C", "O", "H"],
        "descriptor": {
            "type": "se_e2_a",
            "rcut_smth": 0.50,
            "rcut": 6.00,
            "neuron": [25, 50, 100],
            "resnet_dt": False,
            "axis_neuron": 16,
            "seed": 1,
            "_comment": " that's all"
        },
        "fitting_net": {
            "neuron": [240, 240, 240],
            "resnet_dt": True,
            "seed": 1,
            "_comment": " that's all"
        },
        "_comment": " that's all"
    },
    "learning_rate": {
        "type": "exp",
        "decay_steps": 5000,
        "start_lr": 0.001,
        "stop_lr": 3.51e-8,
        "_comment": "that's all"
    },
    "loss": {
        "type": "ener",
        "start_pref_e": 0.02,
        "limit_pref_e": 1,
        "start_pref_f": 1000,
        "limit_pref_f": 1,
        "start_pref_v": 0,
        "limit_pref_v": 0,
        "_comment": " that's all"
    },
    "training": {
        "training_data": {
            "systems": ["/public/home/huangyiru/My-Work/CACFM/aml-intro-main 2/learningnotes3/DeePMD-kit_Tutorial/00.data/training_data"],
            "batch_size": "auto",
            "_comment": "that's all"
        },
        "validation_data": {
            "systems": ["/public/home/huangyiru/My-Work/CACFM/aml-intro-main 2/learningnotes3/DeePMD-kit_Tutorial/00.data/validation_data"],
            "batch_size": 1,
            "numb_btch": 3,
            "_comment": "that's all"
        },
        "numb_steps": 1000,
        "seed": 10,
        "disp_file": "lcurve.out",
        "disp_freq": 100,
        "save_freq": 500,
        "_comment": "that's all"
    },
    "_comment": "that's all"
}

# 保存为 JSON 格式
with open("input.json", "w") as json_file:
    json.dump(data, json_file, indent=4)

print("JSON 数据已保存为 input.json")
# Out:
# JSON 数据已保存为 input.json

# %%
import json

data = {
    "_comment": " model parameters",  # 注释，说明这是模型参数部分
    "model": {  # 模型相关设置
        "type_map": ["C", "O", "H"],  # 原子类型映射，C、O、H
        "descriptor": {  # 描述符相关设置
            "type": "se_e2_a",  # 描述符类型
            "rcut_smth": 0.50,  # 平滑的截断距离
            "rcut": 6.00,  # 截断距离
            "neuron": [25, 50, 100],  # 神经网络层次的神经元数目
            "resnet_dt": False,  # 是否使用残差网络
            "axis_neuron": 16,  # 每一维轴上的神经元数目
            "seed": 1,  # 随机种子
            "_comment": " that's all"  # 注释，表示此部分结束
        },
        "fitting_net": {  # 拟合网络设置
            "neuron": [240, 240, 240],  # 拟合网络的神经元数目
            "resnet_dt": True,  # 是否使用残差网络
            "seed": 1,  # 随机种子
            "_comment": " that's all"  # 注释，表示此部分结束
        },
        "_comment": " that's all"  # 注释，表示模型部分结束
    },
    "learning_rate": {  # 学习率相关设置
        "type": "exp",  # 学习率衰减类型：指数衰减
        "decay_steps": 5000,  # 衰减步数
        "start_lr": 0.001,  # 起始学习率
        "stop_lr": 3.51e-8,  # 最终学习率
        "_comment": "that's all"  # 注释，表示学习率部分结束
    },
    "loss": {  # 损失函数设置
        "type": "ener",  # 损失函数类型：能量损失
        "start_pref_e": 0.02,  # 能量损失的起始权重
        "limit_pref_e": 1,  # 能量损失的最大权重
        "start_pref_f": 1000,  # 力损失的起始权重
        "limit_pref_f": 1,  # 力损失的最大权重
        "start_pref_v": 0,  # 势能损失的起始权重
        "limit_pref_v": 0,  # 势能损失的最大权重
        "_comment": " that's all"  # 注释，表示损失函数部分结束
    },
    "training": {  # 训练相关设置
        "training_data": {  # 训练数据
            "systems": ["/public/home/huangyiru/My-Work/CACFM/aml-intro-main 2/learningnotes3/DeePMD-kit_Tutorial/00.data/training_data"],  # 训练数据路径
            "batch_size": "auto",  # 自动批次大小
            "_comment": "that's all"  # 注释，表示训练数据部分结束
        },
        "validation_data": {  # 验证数据
            "systems": ["/public/home/huangyiru/My-Work/CACFM/aml-intro-main 2/learningnotes3/DeePMD-kit_Tutorial/00.data/validation_data"],  # 验证数据路径
            "batch_size": 1,  # 验证时每批次的大小
            "numb_btch": 3,  # 验证批次数
            "_comment": "that's all"  # 注释，表示验证数据部分结束
        },
        "numb_steps": 1000,  # 训练步数
        "seed": 10,  # 随机种子
        "disp_file": "lcurve.out",  # 输出文件名
        "disp_freq": 100,  # 输出频率
        "save_freq": 500,  # 保存频率
        "_comment": "that's all"  # 注释，表示训练部分结束
    },
    "_comment": "that's all"  # 注释，表示整体配置结束
}

# 保存为 JSON 格式
with open("input.json", "w") as json_file:  # 打开或创建一个 JSON 文件并写入数据
    json.dump(data, json_file, indent=4)  # 将数据以格式化的方式写入文件

print("JSON 数据已保存为 input.json")  # 提示保存成功
# Out:
# JSON 数据已保存为 input.json

# %% [markdown]
# # 训练

# %%
import os
os.makedirs("result", exist_ok=True)
# !cd result && /public/software/mambaforge/envs/deepmd/bin/dp --tf train ../input.json
# Out:
# 2025-05-06 16:57:42.790444: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-06 16:57:42.801072: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-06 16:57:42.804333: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-06 16:57:42.813267: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-06 16:57:43.616287: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, DP_INTRA_OP_PARALLELISM_THREADS, and DP_INTER_OP_PARALLELISM_THREADS. See https://deepmd.rtfd.io/parallelism/ for more information.
# Switch to serial execution due to lack of horovod module.
# [2025-05-06 16:57:49,067] DEEPMD INFO    Calculate neighbor statistics... (add --skip-neighbor-stat to skip this step)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746521869.091422 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.091631 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.091771 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.091956 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.092091 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.092222 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.092357 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.092489 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.092618 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [2025-05-06 16:57:49,092] DEEPMD INFO    If you encounter the error 'an illegal memory access was encountered', this may be due to a TensorFlow issue. To avoid this, set the environment variable DP_INFER_BATCH_SIZE to a smaller value than the last adjusted batch size. The environment variable DP_INFER_BATCH_SIZE controls the inference batch size (nframes * natoms).
# I0000 00:00:1746521869.351582 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.351761 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.351891 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.352015 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.352130 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.352244 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.352365 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.352480 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.352595 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.364089 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.364235 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.364369 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.364494 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.364615 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.364731 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521869.364855 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-06 16:57:49.364979: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21822 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:81:00.0, compute capability: 8.9
# I0000 00:00:1746521869.365213 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-06 16:57:49.365343: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 16484 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:c1:00.0, compute capability: 8.9
# I0000 00:00:1746521869.365720 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-06 16:57:49.365855: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 17406 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:c2:00.0, compute capability: 8.9
# 2025-05-06 16:57:49.372274: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# 2025-05-06 16:57:49.430643: I tensorflow/core/util/cuda_solvers.cc:178] Creating GpuSolver handles for stream 0x3307930
# [2025-05-06 16:57:50,426] DEEPMD INFO    Neighbor statistics: training data with minimal neighbor distance: 1.045921
# [2025-05-06 16:57:50,426] DEEPMD INFO    Neighbor statistics: training data with maximum neighbor size: [1 0 4] (cutoff radius: 6.000000)
# [2025-05-06 16:57:50,449] DEEPMD INFO     _____               _____   __  __  _____           _     _  _
# [2025-05-06 16:57:50,449] DEEPMD INFO    |  __ \             |  __ \ |  \/  ||  __ \         | |   (_)| |
# [2025-05-06 16:57:50,449] DEEPMD INFO    | |  | |  ___   ___ | |__) || \  / || |  | | ______ | | __ _ | |_
# [2025-05-06 16:57:50,449] DEEPMD INFO    | |  | | / _ \ / _ \|  ___/ | |\/| || |  | ||______|| |/ /| || __|
# [2025-05-06 16:57:50,449] DEEPMD INFO    | |__| ||  __/|  __/| |     | |  | || |__| |        |   < | || |_
# [2025-05-06 16:57:50,449] DEEPMD INFO    |_____/  \___| \___||_|     |_|  |_||_____/         |_|\_\|_| \__|
# [2025-05-06 16:57:50,449] DEEPMD INFO    Please read and cite:
# [2025-05-06 16:57:50,449] DEEPMD INFO    Wang, Zhang, Han and E, Comput.Phys.Comm. 228, 178-184 (2018)
# [2025-05-06 16:57:50,449] DEEPMD INFO    Zeng et al, J. Chem. Phys., 159, 054801 (2023)
# [2025-05-06 16:57:50,449] DEEPMD INFO    Zeng et al, arxiv:2502.19161
# [2025-05-06 16:57:50,449] DEEPMD INFO    See https://deepmd.rtfd.io/credits/ for details.
# [2025-05-06 16:57:50,449] DEEPMD INFO    ---------------------------------------------------------------------------------------------------------------
# [2025-05-06 16:57:50,449] DEEPMD INFO    installed to:          /public/software/mambaforge/envs/deepmd/lib/python3.10/site-packages/deepmd
# [2025-05-06 16:57:50,449] DEEPMD INFO    source:                v3.0.2
# [2025-05-06 16:57:50,449] DEEPMD INFO    source branch:         r3.0
# [2025-05-06 16:57:50,449] DEEPMD INFO    source commit:         70bc6d89
# [2025-05-06 16:57:50,449] DEEPMD INFO    source commit at:      2025-03-02 11:04:28 +0800
# [2025-05-06 16:57:50,449] DEEPMD INFO    use float prec:        double
# [2025-05-06 16:57:50,449] DEEPMD INFO    build variant:         cuda
# [2025-05-06 16:57:50,449] DEEPMD INFO    Backend:               TensorFlow
# [2025-05-06 16:57:50,449] DEEPMD INFO    TF ver:                v2.17.0-18-g3c92ac03cab
# [2025-05-06 16:57:50,449] DEEPMD INFO    build with TF ver:     2.17.1
# [2025-05-06 16:57:50,449] DEEPMD INFO    build with TF inc:     /public/software/mambaforge/envs/deepmd/lib/python3.10/site-packages/tensorflow/include/
# [2025-05-06 16:57:50,449] DEEPMD INFO                           /public/software/mambaforge/envs/deepmd/lib/python3.10/site-packages/tensorflow/include/
# [2025-05-06 16:57:50,449] DEEPMD INFO    build with TF lib:
# [2025-05-06 16:57:50,449] DEEPMD INFO    running on:            gpu1
# [2025-05-06 16:57:50,449] DEEPMD INFO    computing device:      gpu:0
# [2025-05-06 16:57:50,449] DEEPMD INFO    CUDA_VISIBLE_DEVICES:  unset
# [2025-05-06 16:57:50,449] DEEPMD INFO    Count of visible GPUs: 3
# [2025-05-06 16:57:50,449] DEEPMD INFO    num_intra_threads:     0
# [2025-05-06 16:57:50,449] DEEPMD INFO    num_inter_threads:     0
# [2025-05-06 16:57:50,449] DEEPMD INFO    ---------------------------------------------------------------------------------------------------------------
# I0000 00:00:1746521870.454164 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521870.454380 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521870.454517 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521870.454649 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521870.454769 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521870.454888 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521870.455007 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521870.455125 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521870.455244 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521870.455438 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521870.455565 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521870.455687 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521870.455810 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-06 16:57:50.455924: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21822 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:81:00.0, compute capability: 8.9
# I0000 00:00:1746521870.455964 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-06 16:57:50.456077: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 16484 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:c1:00.0, compute capability: 8.9
# I0000 00:00:1746521870.456105 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-06 16:57:50.456217: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 17406 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:c2:00.0, compute capability: 8.9
# [2025-05-06 16:57:50,459] DEEPMD INFO    ---Summary of DataSystem: training     -----------------------------------------------
# [2025-05-06 16:57:50,459] DEEPMD INFO    found 1 system(s):
# [2025-05-06 16:57:50,459] DEEPMD INFO                                        system  natoms  bch_sz   n_bch       prob  pbc
# [2025-05-06 16:57:50,459] DEEPMD INFO    -- ePMD-kit_Tutorial/00.data/training_data       5       7      23  1.000e+00    T
# [2025-05-06 16:57:50,459] DEEPMD INFO    --------------------------------------------------------------------------------------
# [2025-05-06 16:57:50,461] DEEPMD INFO    ---Summary of DataSystem: validation   -----------------------------------------------
# [2025-05-06 16:57:50,461] DEEPMD INFO    found 1 system(s):
# [2025-05-06 16:57:50,461] DEEPMD INFO                                        system  natoms  bch_sz   n_bch       prob  pbc
# [2025-05-06 16:57:50,461] DEEPMD INFO    -- MD-kit_Tutorial/00.data/validation_data       5       1      40  1.000e+00    T
# [2025-05-06 16:57:50,461] DEEPMD INFO    --------------------------------------------------------------------------------------
# [2025-05-06 16:57:50,461] DEEPMD INFO    training without frame parameter
# [2025-05-06 16:57:50,461] DEEPMD INFO    data stating... (this step may take long time)
# [2025-05-06 16:57:50,493] DEEPMD INFO    built lr
# [2025-05-06 16:57:51,718] DEEPMD INFO    built network
# [2025-05-06 16:57:53,292] DEEPMD INFO    built training
# [2025-05-06 16:57:53,292] DEEPMD WARNING To get the best performance, it is recommended to adjust the number of threads by setting the environment variables OMP_NUM_THREADS, DP_INTRA_OP_PARALLELISM_THREADS, and DP_INTER_OP_PARALLELISM_THREADS. See https://deepmd.rtfd.io/parallelism/ for more information.
# I0000 00:00:1746521873.292852 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521873.293081 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521873.293214 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521873.293396 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521873.293532 1694011 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-06 16:57:53.293654: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21822 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:81:00.0, compute capability: 8.9
# [2025-05-06 16:57:53,370] DEEPMD INFO    initialize model from scratch
# [2025-05-06 16:57:54,107] DEEPMD INFO    start training at lr 1.00e-03 (== 1.00e-03), decay_step 11, decay_rate 0.893302, final lr will be 3.89e-08
# [2025-05-06 16:57:54,797] DEEPMD INFO    batch       0: trn: rmse = 1.72e+01, rmse_e = 2.75e-01, rmse_f = 5.43e-01, lr = 1.00e-03
# [2025-05-06 16:57:54,798] DEEPMD INFO    batch       0: val: rmse = 1.35e+01, rmse_e = 2.77e-01, rmse_f = 4.26e-01
# I0000 00:00:1746521875.762526 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521875.762776 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521875.762948 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521875.763110 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521875.763246 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521875.763382 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521875.763513 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521875.763645 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521875.763775 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521875.763969 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521875.764107 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521875.764238 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1746521875.764377 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-06 16:57:55.764500: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21822 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:81:00.0, compute capability: 8.9
# I0000 00:00:1746521875.764548 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-06 16:57:55.764678: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 16484 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:c1:00.0, compute capability: 8.9
# I0000 00:00:1746521875.764714 1694531 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-06 16:57:55.764838: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 17406 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:c2:00.0, compute capability: 8.9
# [2025-05-06 16:57:57,027] DEEPMD INFO    batch     100: trn: rmse = 7.04e+00, rmse_e = 7.67e-01, rmse_f = 3.62e-01, lr = 3.62e-04
# [2025-05-06 16:57:57,027] DEEPMD INFO    batch     100: val: rmse = 6.46e+00, rmse_e = 7.69e-01, rmse_f = 3.31e-01
# [2025-05-06 16:57:57,027] DEEPMD INFO    batch     100: total wall time = 2.92 s
# [2025-05-06 16:57:58,179] DEEPMD INFO    batch     200: trn: rmse = 2.76e+00, rmse_e = 4.55e-01, rmse_f = 2.26e-01, lr = 1.31e-04
# [2025-05-06 16:57:58,179] DEEPMD INFO    batch     200: val: rmse = 3.08e+00, rmse_e = 4.52e-01, rmse_f = 2.55e-01
# [2025-05-06 16:57:58,179] DEEPMD INFO    batch     200: total wall time = 1.15 s
# [2025-05-06 16:57:59,353] DEEPMD INFO    batch     300: trn: rmse = 1.93e+00, rmse_e = 3.38e-01, rmse_f = 2.57e-01, lr = 4.75e-05
# [2025-05-06 16:57:59,353] DEEPMD INFO    batch     300: val: rmse = 1.61e+00, rmse_e = 3.42e-01, rmse_f = 2.04e-01
# [2025-05-06 16:57:59,353] DEEPMD INFO    batch     300: total wall time = 1.17 s
# [2025-05-06 16:58:00,526] DEEPMD INFO    batch     400: trn: rmse = 1.36e+00, rmse_e = 2.92e-01, rmse_f = 2.80e-01, lr = 1.72e-05
# [2025-05-06 16:58:00,526] DEEPMD INFO    batch     400: val: rmse = 1.26e+00, rmse_e = 2.93e-01, rmse_f = 2.53e-01
# [2025-05-06 16:58:00,526] DEEPMD INFO    batch     400: total wall time = 1.17 s
# [2025-05-06 16:58:01,696] DEEPMD INFO    batch     500: trn: rmse = 9.03e-01, rmse_e = 2.77e-01, rmse_f = 2.45e-01, lr = 6.24e-06
# [2025-05-06 16:58:01,697] DEEPMD INFO    batch     500: val: rmse = 7.65e-01, rmse_e = 2.81e-01, rmse_f = 1.44e-01
# [2025-05-06 16:58:01,697] DEEPMD INFO    batch     500: total wall time = 1.17 s
# [2025-05-06 16:58:02,022] DEEPMD INFO    saved checkpoint model.ckpt
# [2025-05-06 16:58:03,197] DEEPMD INFO    batch     600: trn: rmse = 7.44e-01, rmse_e = 2.71e-01, rmse_f = 2.40e-01, lr = 2.26e-06
# [2025-05-06 16:58:03,198] DEEPMD INFO    batch     600: val: rmse = 6.98e-01, rmse_e = 2.72e-01, rmse_f = 1.89e-01
# [2025-05-06 16:58:03,198] DEEPMD INFO    batch     600: total wall time = 1.50 s
# [2025-05-06 16:58:04,370] DEEPMD INFO    batch     700: trn: rmse = 7.04e-01, rmse_e = 2.65e-01, rmse_f = 2.81e-01, lr = 8.18e-07
# [2025-05-06 16:58:04,370] DEEPMD INFO    batch     700: val: rmse = 6.46e-01, rmse_e = 2.72e-01, rmse_f = 1.58e-01
# [2025-05-06 16:58:04,370] DEEPMD INFO    batch     700: total wall time = 1.17 s
# [2025-05-06 16:58:05,521] DEEPMD INFO    batch     800: trn: rmse = 6.76e-01, rmse_e = 2.66e-01, rmse_f = 2.82e-01, lr = 2.96e-07
# [2025-05-06 16:58:05,521] DEEPMD INFO    batch     800: val: rmse = 6.39e-01, rmse_e = 2.71e-01, rmse_f = 1.57e-01
# [2025-05-06 16:58:05,521] DEEPMD INFO    batch     800: total wall time = 1.15 s
# [2025-05-06 16:58:06,697] DEEPMD INFO    batch     900: trn: rmse = 6.51e-01, rmse_e = 2.66e-01, rmse_f = 2.53e-01, lr = 1.07e-07
# [2025-05-06 16:58:06,697] DEEPMD INFO    batch     900: val: rmse = 6.49e-01, rmse_e = 2.69e-01, rmse_f = 2.27e-01
# [2025-05-06 16:58:06,698] DEEPMD INFO    batch     900: total wall time = 1.18 s
# [2025-05-06 16:58:07,864] DEEPMD INFO    batch    1000: trn: rmse = 6.50e-01, rmse_e = 2.66e-01, rmse_f = 2.57e-01, lr = 3.89e-08
# [2025-05-06 16:58:07,864] DEEPMD INFO    batch    1000: val: rmse = 6.56e-01, rmse_e = 2.65e-01, rmse_f = 2.60e-01
# [2025-05-06 16:58:07,864] DEEPMD INFO    batch    1000: total wall time = 1.17 s
# [2025-05-06 16:58:08,060] DEEPMD INFO    saved checkpoint model.ckpt
# [2025-05-06 16:58:08,060] DEEPMD INFO    average training time: 0.0113 s/batch (exclude first 100 batches)
# [2025-05-06 16:58:08,060] DEEPMD INFO    finished training
# [2025-05-06 16:58:08,060] DEEPMD INFO    wall time: 14.768 s
